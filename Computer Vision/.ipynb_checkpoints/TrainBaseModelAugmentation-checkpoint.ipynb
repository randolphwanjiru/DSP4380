# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from Dataloader import load_image_dataset
import random
from tensorflow.keras import datasets, layers, models
# Out:
# 2024-04-23 22:46:29.509331: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-23 22:46:30.961280: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#  CompareAugmentation.ipynb     TrainBaseModelAugmentation-New.ipynb
#  Dataloader.ipynb	       TrainBaseModelAugmentation.ipynb
#  Dataloader.py		       TrainBaseModelCopy.h5
#  TrainBaseAugmentation.keras   TrainBaseModelCopy.keras
#  TrainBaseModel-Copy1.ipynb    __pycache__
#  TrainBaseModel.ipynb	      'archive (17)'
#  TrainBaseModel.keras
# Found 202 files belonging to 2 classes.
# Using 162 files for training.
# Using 40 files for validation.
# 2024-04-23 22:46:35.078590: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:984] could not open file to read NUMA node: /sys/bus/pci/devices/0000:3b:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-23 22:46:35.079088: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2024-04-23 22:46:35.571573: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Load image datasets using your Dataloader module
train_ds, valid_ds = load_image_dataset("/home/randolpwanjiru/DSP4380/Computer Vision/archive (17)/pizza_not_pizza")
# Out:
# Found 202 files belonging to 2 classes.
# Using 162 files for training.
# Found 202 files belonging to 2 classes.
# Using 40 files for validation.

# %% [markdown]
# ## Data Augmentation:
# Three types
# * Flip horizontal
# * Rotate image
# * Adjust for brightness

# %%
def augment_data(images, labels):
    # Apply random flip horizontally
    images = tf.image.random_flip_left_right(images)
    
    # Apply random rotation
    images = tf.image.rot90(images, tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32))
    
    # Apply random brightness adjustment
    images = tf.image.random_brightness(images, max_delta=0.2)
    
    images = tf.image.random_contrast(images, lower=0.8, upper=1.2)
    
    return images, labels

# %%
valid_ds_augmented = valid_ds.map(augment_data)

# %%
random.seed(0)
model = models.Sequential()
model.add(layers.Rescaling(1./255))
model.add(layers.Conv2D(128, (3, 3), activation='relu', input_shape=(224,224, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))
model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))
model.add(layers.Conv2D(32, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.25))
model.add(layers.Dense(1))
# Out:
# /home/randolpwanjiru/.local/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
lr = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(lr),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs=10
history = model.fit(  
  train_ds,
  validation_data=valid_ds,
  epochs=epochs,
  verbose=1
)
# Out:
# Epoch 1/10
# 2024-04-23 22:46:41.402337: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 807469056 exceeds 10% of free system memory.
# 2024-04-23 22:46:43.804993: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 807469056 exceeds 10% of free system memory.
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 43s 9s/step - accuracy: 0.6250 - loss: 1.9867
# 2024-04-23 22:46:45.504507: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 807469056 exceeds 10% of free system memory.
# 2024-04-23 22:46:47.901095: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 807469056 exceeds 10% of free system memory.
# 2/6 ━━━━━━━━━━━━━━━━━━━━ 16s 4s/step - accuracy: 0.6016 - loss: 2.1539
# 2024-04-23 22:46:49.669109: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 807469056 exceeds 10% of free system memory.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 27s 4s/step - accuracy: 0.5383 - loss: 2.1672 - val_accuracy: 0.5000 - val_loss: 1.9525
# Epoch 2/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step - accuracy: 0.5065 - loss: 1.9631 - val_accuracy: 0.5000 - val_loss: 1.9279
# Epoch 3/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.4950 - loss: 1.9306 - val_accuracy: 0.5000 - val_loss: 1.9036
# Epoch 4/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.4907 - loss: 1.8975 - val_accuracy: 0.5000 - val_loss: 1.8807
# Epoch 5/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 22s 4s/step - accuracy: 0.5284 - loss: 1.8759 - val_accuracy: 0.5000 - val_loss: 1.8581
# Epoch 6/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.5216 - loss: 1.8504 - val_accuracy: 0.5000 - val_loss: 1.8334
# Epoch 7/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.4839 - loss: 1.8249 - val_accuracy: 0.5000 - val_loss: 1.8100
# Epoch 8/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.5249 - loss: 1.8069 - val_accuracy: 0.5000 - val_loss: 1.7880
# Epoch 9/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 20s 3s/step - accuracy: 0.4870 - loss: 1.7785 - val_accuracy: 0.5000 - val_loss: 1.7665
# Epoch 10/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 3s/step - accuracy: 0.4805 - loss: 1.7573 - val_accuracy: 0.5000 - val_loss: 1.7436

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 10))

for images, labels in valid_ds_augmented.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(images[i]).astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")
# Out:
# 2024-04-23 22:50:32.969632: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
plt.plot(range(len(history.history["loss"])),history.history["loss"],label="Training Loss")
plt.plot(range(len(history.history["val_loss"])),history.history["val_loss"],label="Validation Loss")
plt.legend()

# %%
plt.plot(range(len(history.history["accuracy"])),history.history["accuracy"],label="Training Accuracy")
plt.plot(range(len(history.history["val_accuracy"])),history.history["val_accuracy"],label="Validation Accuracy")
plt.legend()
